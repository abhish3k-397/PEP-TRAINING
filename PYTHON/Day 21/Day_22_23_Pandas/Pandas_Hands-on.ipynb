# %%
import pandas as pd

# %%
marks = pd.Series([85, 90, 78, 92]) 
print(marks)
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# dtype: int64

# %%
city_population = pd.Series({'Delhi': 33800000, 'Mumbai': 20700000, 'Pune': 6800000}) 
print(city_population)
# Out:
# Delhi     33800000
# Mumbai    20700000
# Pune       6800000
# dtype: int64

# %%
import numpy as np 
arr = np.array([10, 20, 30]) 
s = pd.Series(arr) 
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
import pandas as pd

marks = pd.Series(
    [85, 90, 78],
    index=['Math', 'Science', 'English'],
    name='Marks'
)

print(marks)
# Out:
# Math       85
# Science    90
# English    78
# Name: Marks, dtype: int64

# %%
data = { 
    'Name': ['Aditi', 'Rohan', 'Meera'], 
    'Age': [21, 23, 22], 
    'City': ['Delhi', 'Mumbai', 'Pune'] 
} 
df = pd.DataFrame(data) 
print(df)
# Out:
#     Name  Age    City
# 0  Aditi   21   Delhi
# 1  Rohan   23  Mumbai
# 2  Meera   22    Pune

# %%
rows = [['Aditi', 21], ['Rohan', 23]] 
df = pd.DataFrame(rows, columns=['Name', 'Age']) 
print(df)
# Out:
#     Name  Age
# 0  Aditi   21
# 1  Rohan   23

# %%
arr = np.array([[1, 2], [3, 4]]) 
df = pd.DataFrame(arr, columns=['A', 'B']) 
print(df)
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df_csv   = pd.read_csv('students.csv') 
df_excel = pd.read_excel('students.xlsx', sheet_name='Sheet1') 
df_json  = pd.read_json('students.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_csv   = pd.read_csv('students.csv')
#       2 df_excel = pd.read_excel('students.xlsx', sheet_name='Sheet1')
#       3 df_json  = pd.read_json('students.json')
#
# ...

# %%
df = pd.read_csv('sales.csv') 
df = pd.read_csv('sales.csv', usecols=['Date', 'Revenue'], parse_dates=['Date'])

# %%
df = pd.read_excel('sales.xlsx', sheet_name='Q1') 
# requires: pip install openpyxl

# %%
tables = pd.read_html('https://example.com/stats-page') 
df = tables[0]   # returns a LIST of DataFrames, one per <table> 
# requires: pip install lxml

# %%
df = pd.read_json('sales.json')

# %%
df.head(1)
# Out:
#    A  B
# 0  1  2

# %%
df.tail(1)
# Out:
#    A  B
# 1  3  4

# %%
df.sample(1)
# Out:
#    A  B
# 0  1  2

# %%
df.info
# Out:
# <bound method DataFrame.info of    A  B
# 0  1  2
# 1  3  4>

# %%
df[df['Age'] > 22] 
df[(df['Age'] > 22) & (df['City'] == 'Pune')]     # AND -> & 
df[(df['City'] == 'Pune') | (df['City'] == 'Delhi')]  # OR -> |

# %%
df[df['City'].isin(['Delhi', 'Pune'])]

# %%
df.query("Age > 22 and City == 'Pune'")

# %%
df.isnull()          # boolean mask, True where missing 
df.isnull().sum()    # count of missing values per column 
df.notnull()
